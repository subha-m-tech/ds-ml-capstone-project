# %%
import pandas as pd

# %%
updated_dataset = pd.read_csv("../final_mob_dataset.csv")

# %%
updated_dataset
# Out:
#      product id  price   sale  weight  resolution    ppi  cpu core  cpu freq  \
# 0           203   2357   10.0   135.0        5.20  424.0         8     1.350
# 1           880   1749   10.0   125.0        4.00  233.0         2     1.300
# 2            40   1916   10.0   110.0        4.70  312.0         4     1.200
# 3            99   1315   11.0   118.5        4.00  233.0         2     1.300
# 4           880   1749   11.0   125.0        4.00  233.0         2     1.300
# ..          ...    ...    ...     ...         ...    ...       ...       ...
# 156        1206   3551  899.5   178.0        5.46  538.0         4     1.875
# 157        1296   3211  899.5   170.0        5.50  534.0         4     1.975
# 158         856   3260  899.5   150.0        5.50  401.0         8     2.200
# 159        1296   3211  899.5   170.0        5.50  534.0         4     1.975
# 160        1131   2536  899.5   202.0        6.00  367.0         8     1.500
#
#      internal mem    ram  rearcam  front cam  battery  thickness
# 0            16.0  3.000    13.00        8.0     2610        7.4
# 1             4.0  1.000     3.15        0.0     1700        9.9
# 2             8.0  1.500    13.00        5.0     2000        7.6
# 3             4.0  0.512     3.15        0.0     1400       11.0
# 4             4.0  1.000     3.15        0.0     1700        9.9
# ..            ...    ...      ...        ...      ...        ...
# 156          68.0  6.000    12.00       16.0     4080        8.4
# 157          68.0  6.000    20.00        8.0     3400        7.9
# 158          64.0  4.000    20.00       20.0     3000        6.8
# 159          68.0  6.000    20.00        8.0     3400        7.9
# 160          16.0  3.000    21.50       16.0     2700        8.4
#
# [161 rows x 14 columns]

# %%
updated_dataset
# Out:
#      product id  price   sale  weight  resolution    ppi  cpu core  cpu freq  \
# 0           203   2357   10.0   135.0        5.20  424.0         8     1.350
# 1           880   1749   10.0   125.0        4.00  233.0         2     1.300
# 2            40   1916   10.0   110.0        4.70  312.0         4     1.200
# 3            99   1315   11.0   118.5        4.00  233.0         2     1.300
# 4           880   1749   11.0   125.0        4.00  233.0         2     1.300
# ..          ...    ...    ...     ...         ...    ...       ...       ...
# 156        1206   3551  899.5   178.0        5.46  538.0         4     1.875
# 157        1296   3211  899.5   170.0        5.50  534.0         4     1.975
# 158         856   3260  899.5   150.0        5.50  401.0         8     2.200
# 159        1296   3211  899.5   170.0        5.50  534.0         4     1.975
# 160        1131   2536  899.5   202.0        6.00  367.0         8     1.500
#
#      internal mem    ram  rearcam  front cam  battery  thickness
# 0            16.0  3.000    13.00        8.0     2610        7.4
# 1             4.0  1.000     3.15        0.0     1700        9.9
# 2             8.0  1.500    13.00        5.0     2000        7.6
# 3             4.0  0.512     3.15        0.0     1400       11.0
# 4             4.0  1.000     3.15        0.0     1700        9.9
# ..            ...    ...      ...        ...      ...        ...
# 156          68.0  6.000    12.00       16.0     4080        8.4
# 157          68.0  6.000    20.00        8.0     3400        7.9
# 158          64.0  4.000    20.00       20.0     3000        6.8
# 159          68.0  6.000    20.00        8.0     3400        7.9
# 160          16.0  3.000    21.50       16.0     2700        8.4
#
# [161 rows x 14 columns]

# %%
updated_dataset.columns
# Out:
# Index(['product id', 'price', 'sale', 'weight', 'resolution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'rearcam', 'front cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
feature_list = pd.read_csv("../final_features.csv")

# %%
features = feature_list.loc[:, "features_list"]

# %%
updated_dataset[features]
# Out:
#        ppi  cpu core  internal mem    ram  cpu freq  rearcam  thickness  \
# 0    424.0         8          16.0  3.000     1.350    13.00        7.4
# 1    233.0         2           4.0  1.000     1.300     3.15        9.9
# 2    312.0         4           8.0  1.500     1.200    13.00        7.6
# 3    233.0         2           4.0  0.512     1.300     3.15       11.0
# 4    233.0         2           4.0  1.000     1.300     3.15        9.9
# ..     ...       ...           ...    ...       ...      ...        ...
# 156  538.0         4          68.0  6.000     1.875    12.00        8.4
# 157  534.0         4          68.0  6.000     1.975    20.00        7.9
# 158  401.0         8          64.0  4.000     2.200    20.00        6.8
# 159  534.0         4          68.0  6.000     1.975    20.00        7.9
# 160  367.0         8          16.0  3.000     1.500    21.50        8.4
#
#      battery
# 0       2610
# 1       1700
# 2       2000
# 3       1400
# 4       1700
# ..       ...
# 156     4080
# 157     3400
# 158     3000
# 159     3400
# 160     2700
#
# [161 rows x 8 columns]

# %%
independent_variable = updated_dataset[features]
dependent_variable = updated_dataset[['price']]

# %%
# commented below lines as GridSearchCV will split the data into train and test set
# from sklearn.model_selection import train_test_split
# X_train, X_test,y_train,  y_test = train_test_split(independent_variable, dependent_variable, random_state=0, 
#                                                     test_size=0.30)

# %%
# commented below lines as GridSearchCV will split the data into train and test set
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion': ['mse', 'mae', 'friedman_mse'],
             'max_features': ['auto', 'sqrt', 'log2'],
             'splitter': ['best', 'random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose =3, n_jobs=-1)

# %%
grid.fit(independent_variable, dependent_variable)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# /Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 70 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 22 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'absolute_error', 'poisson', 'squared_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'squared_error', 'friedman_mse', 'absolute_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'absolute_error', 'squared_error', 'friedman_mse'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'poisson', 'absolute_error', 'squared_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'absolute_error', 'friedman_mse', 'squared_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'absolute_error', 'poisson', 'squared_error'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'squared_error', 'friedman_mse', 'absolute_error'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'absolute_error', 'squared_error', 'friedman_mse'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'absolute_error', 'friedman_mse', 'squared_error'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.82364493 0.81793242 0.74960543 0.82610498]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_

# %%
re_df = pd.DataFrame.from_dict(re)

# %%
re_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000546      0.000219         0.000000        0.000000
# 1        0.000372      0.000080         0.000000        0.000000
# 2        0.000657      0.000066         0.000000        0.000000
# 3        0.000733      0.000059         0.000000        0.000000
# 4        0.000474      0.000254         0.000000        0.000000
# 5        0.000462      0.000264         0.000000        0.000000
# 6        0.000602      0.000206         0.000000        0.000000
# 7        0.000456      0.000214         0.000000        0.000000
# 8        0.000487      0.000231         0.000000        0.000000
# 9        0.000596      0.000433         0.000000        0.000000
# 10       0.000284      0.000093         0.000000        0.000000
# 11       0.000340      0.000194         0.000000        0.000000
# 12       0.000656      0.000256         0.000000        0.000000
# 13       0.000278      0.000133         0.000000        0.000000
# 14       0.002327      0.000805         0.001061        0.000567
# 15       0.004060      0.002491         0.001995        0.000760
# 16       0.001676      0.000896         0.000979        0.000565
# 17       0.001475      0.000701         0.000709        0.000077
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 1   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 4   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 5   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 6   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 7   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 10  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 11  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.815885
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.814120
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.715599
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.838749
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.773607           0.874472           0.861194
# 15           0.760616           0.866389           0.752337
# 16           0.527381           0.725651           0.916184
# 17           0.804867           0.810026           0.821489
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                5
# 1                 NaN              NaN             NaN                5
# 2                 NaN              NaN             NaN                5
# 3                 NaN              NaN             NaN                5
# 4                 NaN              NaN             NaN                5
# 5                 NaN              NaN             NaN                5
# 6                 NaN              NaN             NaN                5
# 7                 NaN              NaN             NaN                5
# 8                 NaN              NaN             NaN                5
# 9                 NaN              NaN             NaN                5
# 10                NaN              NaN             NaN                5
# 11                NaN              NaN             NaN                5
# 12                NaN              NaN             NaN                5
# 13                NaN              NaN             NaN                5
# 14           0.793066         0.823645        0.038710                2
# 15           0.896200         0.817932        0.056703                3
# 16           0.863212         0.749605        0.135476                4
# 17           0.855393         0.826105        0.018700                1

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'}

# %%
grid.best_score_
# Out:
# 0.8261049785326133

# %%
ppi = int(input("ppi"))
cpu_core = int(input("cpu core:"))
internal_mem = float(input("internal mem:"))
ram = float(input("ram:"))
cpu_freq = float(input("cpu freq:"))
rearcam = float(input("rearcam:"))
thickness = float(input("thickness:"))
battery = int(input("battery:"))
# Out:
# ppi 424
# cpu core: 8
# internal mem: 16.0
# ram: 3.0
# cpu freq: 1.350
# rearcam: 13.0
# thickness: 7.4
# battery: 2610

# %%
result = grid.predict([[ppi, cpu_core, internal_mem, ram, cpu_freq,rearcam,thickness,battery]])
# Out:
# /Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([2357.])
# [CV 4/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.752 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.839 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.810 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.761 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.816 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.774 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.793 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.716 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.916 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.855 total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.874 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.896 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.821 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.814 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.726 total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_features=sqrt, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_features=sqrt, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_features=log2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_features=log2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.861 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.866 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.527 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.863 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.805 total time=   0.0s
