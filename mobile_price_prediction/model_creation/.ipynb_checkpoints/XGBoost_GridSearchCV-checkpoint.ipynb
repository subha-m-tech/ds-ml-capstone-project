# %%
import pandas as pd

# %%
updated_dataset = pd.read_csv("../final_mob_dataset.csv")

# %%
updated_dataset
# Out:
#      product id  price   sale  weight  resolution    ppi  cpu core  cpu freq  \
# 0           203   2357   10.0   135.0        5.20  424.0         8     1.350
# 1           880   1749   10.0   125.0        4.00  233.0         2     1.300
# 2            40   1916   10.0   110.0        4.70  312.0         4     1.200
# 3            99   1315   11.0   118.5        4.00  233.0         2     1.300
# 4           880   1749   11.0   125.0        4.00  233.0         2     1.300
# ..          ...    ...    ...     ...         ...    ...       ...       ...
# 156        1206   3551  899.5   178.0        5.46  538.0         4     1.875
# 157        1296   3211  899.5   170.0        5.50  534.0         4     1.975
# 158         856   3260  899.5   150.0        5.50  401.0         8     2.200
# 159        1296   3211  899.5   170.0        5.50  534.0         4     1.975
# 160        1131   2536  899.5   202.0        6.00  367.0         8     1.500
#
#      internal mem    ram  rearcam  front cam  battery  thickness
# 0            16.0  3.000    13.00        8.0     2610        7.4
# 1             4.0  1.000     3.15        0.0     1700        9.9
# 2             8.0  1.500    13.00        5.0     2000        7.6
# 3             4.0  0.512     3.15        0.0     1400       11.0
# 4             4.0  1.000     3.15        0.0     1700        9.9
# ..            ...    ...      ...        ...      ...        ...
# 156          68.0  6.000    12.00       16.0     4080        8.4
# 157          68.0  6.000    20.00        8.0     3400        7.9
# 158          64.0  4.000    20.00       20.0     3000        6.8
# 159          68.0  6.000    20.00        8.0     3400        7.9
# 160          16.0  3.000    21.50       16.0     2700        8.4
#
# [161 rows x 14 columns]

# %%
# As there is no categorical variable in the dataset so we can ignore this step
# updated_dataset = pd.get_dummies(dataset, drop_first=True)

# %%
updated_dataset.columns
# Out:
# Index(['product id', 'price', 'sale', 'weight', 'resolution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'rearcam', 'front cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
feature_list = pd.read_csv("../final_features.csv")

# %%
features = feature_list.loc[:, "features_list"]

# %%
updated_dataset[features]
# Out:
#        ppi  cpu core  internal mem    ram  cpu freq  rearcam  thickness  \
# 0    424.0         8          16.0  3.000     1.350    13.00        7.4
# 1    233.0         2           4.0  1.000     1.300     3.15        9.9
# 2    312.0         4           8.0  1.500     1.200    13.00        7.6
# 3    233.0         2           4.0  0.512     1.300     3.15       11.0
# 4    233.0         2           4.0  1.000     1.300     3.15        9.9
# ..     ...       ...           ...    ...       ...      ...        ...
# 156  538.0         4          68.0  6.000     1.875    12.00        8.4
# 157  534.0         4          68.0  6.000     1.975    20.00        7.9
# 158  401.0         8          64.0  4.000     2.200    20.00        6.8
# 159  534.0         4          68.0  6.000     1.975    20.00        7.9
# 160  367.0         8          16.0  3.000     1.500    21.50        8.4
#
#      battery
# 0       2610
# 1       1700
# 2       2000
# 3       1400
# 4       1700
# ..       ...
# 156     4080
# 157     3400
# 158     3000
# 159     3400
# 160     2700
#
# [161 rows x 8 columns]

# %%
independent_variable = updated_dataset[features]
dependent_variable = updated_dataset[['price']]

# %%
# commented below lines as GridSearchCV will split the data into train and test set
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(independent_variable, dependent_variable, random_state=0, test_size=0.30)

# %%
# commented below lines as GridSearchCV will split the data into train and test set
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train  = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: numpy in /Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages (from xgboost) (1.26.2)
# Requirement already satisfied: scipy in /Users/subhaarunpandian/anaconda3/envs/mlenv/lib/python3.11/site-packages (from xgboost) (1.11.4)

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
param_grid = {'max_depth': [3,4,5], 
              'learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0],
              'n_estimators': [50, 100, 500, 1000, 5000]}
grid = GridSearchCV(XGBRegressor(), param_grid, refit=True, verbose = 3, n_jobs = -1)

# %%
grid.fit(independent_variable, dependent_variable)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [50, 100, 500, 1000, 5000]},
#              verbose=3)

# %%
cv_results = grid.cv_results_

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}

# %%
cv_results_df = pd.DataFrame.from_dict(cv_results)

# %%
cv_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009272      0.002520         0.002921        0.001267
# 1        0.016617      0.005456         0.003931        0.002360
# 2        0.056312      0.016840         0.001717        0.000863
# 3        0.087324      0.014531         0.002353        0.001305
# 4        0.447739      0.038426         0.004699        0.002528
# ..            ...           ...              ...             ...
# 70       0.007203      0.001602         0.001242        0.000737
# 71       0.008293      0.002595         0.001250        0.000667
# 72       0.030727      0.008690         0.001370        0.000396
# 73       0.052338      0.004476         0.001554        0.000832
# 74       0.213454      0.019585         0.001382        0.000100
#
#    param_learning_rate param_max_depth param_n_estimators  \
# 0               0.0001               3                 50
# 1               0.0001               3                100
# 2               0.0001               3                500
# 3               0.0001               3               1000
# 4               0.0001               3               5000
# ..                 ...             ...                ...
# 70                 1.0               5                 50
# 71                 1.0               5                100
# 72                 1.0               5                500
# 73                 1.0               5               1000
# 74                 1.0               5               5000
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.0001, 'max_depth': 3, 'n_e...          -0.015912
# 1   {'learning_rate': 0.0001, 'max_depth': 3, 'n_e...          -0.008815
# 2   {'learning_rate': 0.0001, 'max_depth': 3, 'n_e...           0.045785
# 3   {'learning_rate': 0.0001, 'max_depth': 3, 'n_e...           0.105301
# 4   {'learning_rate': 0.0001, 'max_depth': 3, 'n_e...           0.441391
# ..                                                ...                ...
# 70  {'learning_rate': 1.0, 'max_depth': 5, 'n_esti...           0.750050
# 71  {'learning_rate': 1.0, 'max_depth': 5, 'n_esti...           0.750050
# 72  {'learning_rate': 1.0, 'max_depth': 5, 'n_esti...           0.750050
# 73  {'learning_rate': 1.0, 'max_depth': 5, 'n_esti...           0.750050
# 74  {'learning_rate': 1.0, 'max_depth': 5, 'n_esti...           0.750050
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.001964          -0.000916          -0.053931
# 1            0.008142           0.007417          -0.046883
# 2            0.057625           0.071503           0.009535
# 3            0.114372           0.145491           0.078064
# 4            0.450951           0.526119           0.436814
# ..                ...                ...                ...
# 70           0.743338           0.942256           0.903632
# 71           0.743338           0.942256           0.903632
# 72           0.743338           0.942256           0.903632
# 73           0.743338           0.942256           0.903632
# 74           0.743338           0.942256           0.903632
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.103523        -0.034464        0.039862               75
# 1           -0.095827        -0.027193        0.039705               72
# 2           -0.036659         0.029558        0.038977               69
# 3            0.031626         0.094971        0.038298               63
# 4            0.440741         0.459203        0.033779               57
# ..                ...              ...             ...              ...
# 70           0.882400         0.844335        0.082029               28
# 71           0.882400         0.844335        0.082029               28
# 72           0.882400         0.844335        0.082029               28
# 73           0.882400         0.844335        0.082029               28
# 74           0.882400         0.844335        0.082029               28
#
# [75 rows x 16 columns]

# %%
grid.best_score_
# Out:
# 0.8902720594674864

# %%
ppi = int(input("ppi"))
cpu_core = int(input("cpu core:"))
internal_mem = float(input("internal mem:"))
ram = float(input("ram:"))
cpu_freq = float(input("cpu freq:"))
rearcam = float(input("rearcam:"))
thickness = float(input("thickness:"))
battery = int(input("battery:"))
# Out:
# ppi 424
# cpu core: 8
# internal mem: 16.0
# ram: 3.0
# cpu freq: 1.350
# rearcam: 13.0
# thickness: 7.4
# battery: 2610

# %%
result = grid.predict([[ppi, cpu_core, internal_mem, ram, cpu_freq,rearcam,thickness,battery]])

# %%
result
# Out:
# array([2475.0286], dtype=float32)
